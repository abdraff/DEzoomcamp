# %%
import pandas as pd
from time import time
from sqlalchemy import create_engine
import psycopg2  

green_tripdata_2019_df_iter = pd.read_csv('green_tripdata_2019-10.csv', iterator=True, chunksize=1000)
green_tripdata_2019_df = pd.read_csv('green_tripdata_2019-10.csv', nrows=100)
engine = create_engine('postgresql://postgres:postgres@localhost:5433/ny_taxi')

green_tripdata_2019_df.lpep_pickup_datetime = pd.to_datetime(green_tripdata_2019_df.lpep_pickup_datetime)
green_tripdata_2019_df.lpep_dropoff_datetime = pd.to_datetime(green_tripdata_2019_df.lpep_dropoff_datetime)

# print(pd.io.sql.get_schema(taxi_zone_lookup_df, name ='taxi_zone_lookup', con=engine))
print(pd.io.sql.get_schema(green_tripdata_2019_df, name ='green_tripdata_2019', con=engine))

green_tripdata_2019_df.head(n=0).to_sql(name='green_tripdata_2019', con=engine, if_exists='replace')

while True:
    try:
        t_start = time()
    
        green_tripdata_2019_df = next(green_tripdata_2019_df_iter)

        green_tripdata_2019_df.lpep_pickup_datetime = pd.to_datetime(green_tripdata_2019_df.lpep_pickup_datetime)
        green_tripdata_2019_df.lpep_dropoff_datetime = pd.to_datetime(green_tripdata_2019_df.lpep_dropoff_datetime)

        green_tripdata_2019_df.to_sql(name='green_tripdata_2019', con=engine, if_exists='append')

        t_end = time()

        print('inserted another chunk..., took %.3f second' % (t_end - t_start))
        
    except StopIteration:  
        # Break the loop if there are no more chunks to read  
        print("No more data to read. Exiting the loop.")  
        break
# Out:
# CREATE TABLE green_tripdata_2019 (
# 	"VendorID" BIGINT,
# 	lpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	lpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" BIGINT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type BIGINT,
# 	trip_type BIGINT,
# 	congestion_surcharge FLOAT(53)
# )
#
#
# inserted another chunk..., took 0.171 second
# inserted another chunk..., took 0.118 second
# inserted another chunk..., took 0.110 second
# inserted another chunk..., took 0.119 second
# inserted another chunk..., took 0.095 second
# inserted another chunk..., took 0.101 second
# inserted another chunk..., took 0.096 second
# inserted another chunk..., took 0.094 second
# ...

# %%
green_tripdata_2019_df.lpep_pickup_datetime = pd.to_datetime(green_tripdata_2019_df.lpep_pickup_datetime)
green_tripdata_2019_df.lpep_dropoff_datetime = pd.to_datetime(green_tripdata_2019_df.lpep_dropoff_datetime)

# green_tripdata_2019_df.head(n=0).to_sql(name='green_tripdata_2019', con=engine)
print(pd.io.sql.get_shcema(green_tripdata_2019_df, green_tripdata_2019, con=engine))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [5], in <cell line: 5>()
#       2 green_tripdata_2019_df.lpep_dropoff_datetime = pd.to_datetime(green_tripdata_2019_df.lpep_dropoff_datetime)
#       4 # green_tripdata_2019_df.head(n=0).to_sql(name='green_tripdata_2019', con=engine)
# ----> 5 print(pd.io.sql.get_shcema(green_tripdata_2019_df, green_tripdata_2019, con=engine))
#
# AttributeError: module 'pandas.io.sql' has no attribute 'get_shcema'

# %%
taxi_zone_lookup_df = pd.read_csv('taxi_zone_lookup.csv')

taxi_zone_lookup_df.to_sql(name='taxi_zone_lookup', con=engine, if_exists='replace')
